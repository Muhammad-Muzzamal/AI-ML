# %% [markdown]
# series and dataframe

# %%
import pandas as pd

# %%
ages = pd.Series([1, 2, 3, 4], name="age")
ages
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# Name: age, dtype: int64

# %%
students = pd.DataFrame({
    "name" : ["Ali", "Muzzamal"],
    "age" : [19, 21],
    "passed" : [True, False]
})

# %%
students
# Out:
#        name  age  passed
# 0       Ali   19    True
# 1  Muzzamal   21   False

# %%
data = {
    "Name": ["Ali", "Ahmed", "Sara", "Usman", "Ayesha"],
    "Age": [20, 21, 19, 22, 20],
    "Marks": [85, 78, 92, 70, 88]
}

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#      Name  Age  Marks
# 0     Ali   20     85
# 1   Ahmed   21     78
# 2    Sara   19     92
# 3   Usman   22     70
# 4  Ayesha   20     88

# %%
df.head()
# Out:
#      Name  Age  Marks
# 0     Ali   20     85
# 1   Ahmed   21     78
# 2    Sara   19     92
# 3   Usman   22     70
# 4  Ayesha   20     88

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    5 non-null      str
#  1   Age     5 non-null      int64
#  2   Marks   5 non-null      int64
# dtypes: int64(2), str(1)
# memory usage: 275.0 bytes

# %%
df.describe(include='all')
# Out:
#        Name        Age     Marks
# count     5   5.000000   5.00000
# unique    5        NaN       NaN
# top     Ali        NaN       NaN
# freq      1        NaN       NaN
# mean    NaN  20.400000  82.60000
# std     NaN   1.140175   8.70632
# min     NaN  19.000000  70.00000
# 25%     NaN  20.000000  78.00000
# 50%     NaN  20.000000  85.00000
# 75%     NaN  21.000000  88.00000
# max     NaN  22.000000  92.00000

# %%
df = pd.read_csv("work/pandas/student_data.csv")
df
# Out:
#     student_id first_name last_name gender  age  grade_level    subject  \
# 0         1001        Ali      Khan      M   15            9       Math
# 1         1002       Sara     Ahmed      F   16           10    Science
# 2         1003      Bilal   Hussain      M   14            8    English
# 3         1004     Ayesha      Raza      F   15            9       Math
# 4         1005      Usman     Malik      M   17           11    Physics
# 5         1006     Fatima     Iqbal      F   16           10  Chemistry
# 6         1007      Hamza    Sheikh      M   14            8    Science
# 7         1008     Zainab     Tariq      F   17           11    Biology
# 8         1009       Omar    Farooq      M   15            9    English
# 9         1010      Mehak    Younas      F   14            8       Math
# 10        1011       Saad  Chaudhry      M   16           10    Physics
# 11        1012       Hira     Nawaz      F   15            9  Chemistry
# ...

# %%
import numpy as np

# %%
np.dtype(df["test_score"])
# Out:
# dtype('int64')

# %%
new_df = df[["first_name", "last_name", "gender"]]

# %%
new_df
# Out:
#    first_name last_name gender
# 0         Ali      Khan      M
# 1        Sara     Ahmed      F
# 2       Bilal   Hussain      M
# 3      Ayesha      Raza      F
# 4       Usman     Malik      M
# 5      Fatima     Iqbal      F
# 6       Hamza    Sheikh      M
# 7      Zainab     Tariq      F
# 8        Omar    Farooq      M
# 9       Mehak    Younas      F
# 10       Saad  Chaudhry      M
# 11       Hira     Nawaz      F
# 12      Talha     Aslam      M
# 13       Nida      Baig      F
# 14     Waleed  Siddiqui      M
# 15       Amna   Qureshi      F
# 16     Faisal     Anwar      M
# 17      Rabia    Hameed      F
# 18     Danish      Riaz      M
# 19       Sana    Yousaf      F

# %%
indexed = new_df.set_index("first_name")

# %%
indexed
# Out:
#            last_name gender
# first_name
# Ali             Khan      M
# Sara           Ahmed      F
# Bilal        Hussain      M
# Ayesha          Raza      F
# Usman          Malik      M
# Fatima         Iqbal      F
# Hamza         Sheikh      M
# Zainab         Tariq      F
# Omar          Farooq      M
# Mehak         Younas      F
# Saad        Chaudhry      M
# Hira           Nawaz      F
# Talha          Aslam      M
# Nida            Baig      F
# Waleed      Siddiqui      M
# Amna         Qureshi      F
# Faisal         Anwar      M
# Rabia         Hameed      F
# Danish          Riaz      M
# Sana          Yousaf      F

# %%
print(indexed.loc[["Ali", "Sara"], "gender"])
# Out:
# first_name
# Ali     M
# Sara    F
# Name: gender, dtype: str

# %%
df.iloc[0:4, 0:3]
# Out:
#    student_id first_name last_name
# 0        1001        Ali      Khan
# 1        1002       Sara     Ahmed
# 2        1003      Bilal   Hussain
# 3        1004     Ayesha      Raza

# %%
df.head()
# Out:
#    student_id first_name last_name gender  age  grade_level  subject  \
# 0        1001        Ali      Khan      M   15            9     Math
# 1        1002       Sara     Ahmed      F   16           10  Science
# 2        1003      Bilal   Hussain      M   14            8  English
# 3        1004     Ayesha      Raza      F   15            9     Math
# 4        1005      Usman     Malik      M   17           11  Physics
#
#    test_score  attendance_percentage  study_hours_per_week extracurricular  \
# 0          78                     92                     6         Cricket
# 1          85                     95                     8     Debate Club
# 2          66                     80                     4             NaN
# 3          91                     98                    10      Chess Club
# 4          73                     85                     5        Football
#
#          city
# 0      Lahore
# 1     Karachi
# 2   Islamabad
# 3      Lahore
# 4  Faisalabad

# %%
df[(df["attendance_percentage"] > 75) & (df["gender"] == 'M')]
# Out:
#     student_id first_name last_name gender  age  grade_level  subject  \
# 0         1001        Ali      Khan      M   15            9     Math
# 2         1003      Bilal   Hussain      M   14            8  English
# 4         1005      Usman     Malik      M   17           11  Physics
# 8         1009       Omar    Farooq      M   15            9  English
# 12        1013      Talha     Aslam      M   17           11  Science
# 16        1017     Faisal     Anwar      M   17           11  Physics
# 18        1019     Danish      Riaz      M   15            9  Science
#
#     test_score  attendance_percentage  study_hours_per_week extracurricular  \
# 0           78                     92                     6         Cricket
# 2           66                     80                     4             NaN
# 4           73                     85                     5        Football
# 8           70                     88                     4         Cricket
# ...

# %%
df["test_percentage"] = df["test_score"] / 100

# %%
df["passed"] = df["test_score"] >= 50

# %%
df["future_doctor"] = df["subject"] == "Biology"

# %%
df
# Out:
#     student_id first_name last_name gender  age  grade_level    subject  \
# 0         1001        Ali      Khan      M   15            9       Math
# 1         1002       Sara     Ahmed      F   16           10    Science
# 2         1003      Bilal   Hussain      M   14            8    English
# 3         1004     Ayesha      Raza      F   15            9       Math
# 4         1005      Usman     Malik      M   17           11    Physics
# 5         1006     Fatima     Iqbal      F   16           10  Chemistry
# 6         1007      Hamza    Sheikh      M   14            8    Science
# 7         1008     Zainab     Tariq      F   17           11    Biology
# 8         1009       Omar    Farooq      M   15            9    English
# 9         1010      Mehak    Younas      F   14            8       Math
# 10        1011       Saad  Chaudhry      M   16           10    Physics
# 11        1012       Hira     Nawaz      F   15            9  Chemistry
# ...

# %%
df = pd.read_csv("work/pandas/student_data_messy.csv")

# %%
df.head()
# Out:
#    student_id first_name last_name  gender   age  grade_level  subject  \
# 0        1001        Ali      Khan       M  15.0            9     Math
# 1        1002       Sara     Ahmed  Female  16.0           10  science
# 2        1003      Bilal   Hussain    male  14.0            8  English
# 3        1004     Ayesha      Raza       F  15.0            9     Math
# 4        1005      Usman     Malik       M  17.0           11  Physics
#
#    test_score  attendance_percentage  study_hours_per_week        city
# 0        78.0                   92.0                   6.0      Lahore
# 1        85.0                   95.0                   8.0     Karachi
# 2         NaN                   80.0                   4.0   Islamabad
# 3        91.0                   98.0                  10.0      Lahore
# 4        73.0                    NaN                   5.0  Faisalabad

# %%
df.shape
# Out:
# (21, 11)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 21 entries, 0 to 20
# Data columns (total 11 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   student_id             21 non-null     int64
#  1   first_name             21 non-null     str
#  2   last_name              21 non-null     str
#  3   gender                 21 non-null     str
#  4   age                    20 non-null     float64
#  5   grade_level            21 non-null     int64
#  6   subject                21 non-null     str
#  7   test_score             19 non-null     float64
#  8   attendance_percentage  20 non-null     float64
#  9   study_hours_per_week   20 non-null     float64
#  10  city                   21 non-null     str
# dtypes: float64(4), int64(2), str(5)
# memory usage: 2.5 KB

# %%
df.describe()
# Out:
#         student_id        age  grade_level  test_score  attendance_percentage  \
# count    21.000000  20.000000    21.000000   19.000000              20.000000
# mean   1010.476190  15.400000     8.476190   81.578947              87.400000
# std       5.767313   1.095445     4.154745   20.353312               9.338094
# min    1001.000000  14.000000    -9.000000   55.000000              68.000000
# 25%    1006.000000  14.750000     8.000000   70.500000              81.500000
# 50%    1010.000000  15.000000     9.000000   82.000000              90.500000
# 75%    1015.000000  16.000000    10.000000   88.500000              94.250000
# max    1020.000000  17.000000    11.000000  150.000000              99.000000
#
#        study_hours_per_week
# count             20.000000
# mean               6.000000
# std                2.247806
# min                2.000000
# 25%                4.000000
# 50%                6.000000
# 75%                8.000000
# max               10.000000

# %%
df.duplicated().sum()
# Out:
# np.int64(1)

# %%
df.drop_duplicates(inplace=True)

# %%
df.isnull().sum()
# Out:
# student_id               0
# first_name               0
# last_name                0
# gender                   0
# age                      1
# grade_level              0
# subject                  0
# test_score               2
# attendance_percentage    1
# study_hours_per_week     1
# city                     0
# dtype: int64

# %%
df.dropna(axis=0, inplace=True)

# %%
df.isnull().sum()
# Out:
# student_id               0
# first_name               0
# last_name                0
# gender                   0
# age                      0
# grade_level              0
# subject                  0
# test_score               0
# attendance_percentage    0
# study_hours_per_week     0
# city                     0
# dtype: int64

# %%
df["gender"] = df["gender"].replace(["Female", "female"], "F")

# %%
df = df.set_index("student_id")

# %%
df.columns
# Out:
# Index(['first_name', 'last_name', 'gender', 'age', 'grade_level', 'subject',
#        'test_score', 'attendance_percentage', 'study_hours_per_week', 'city'],
#       dtype='str')
