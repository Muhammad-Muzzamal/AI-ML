# %% [markdown]
# # Gradient Descient from Scratch

# %%
from sklearn.datasets import make_regression
import matplotlib.pyplot as plt
import numpy as np

# %%
X, y = make_regression(n_samples=100, n_features=1, n_informative=1, n_targets=1, noise=20)

# %%
plt.scatter(X, y)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()

# %%
lr.fit(X, y)
# Out:
# LinearRegression()

# %%
lr.coef_
# Out:
# array([30.74866783])

# %%
lr.intercept_
# Out:
# np.float64(-1.3774820793640856)

# %%
class GDRegressor:
    def __init__(self, learning_rate, epochs):
        self.m = 30.74
        self.b = -120
        self.lr = learning_rate
        self.epochs = epochs

    def fit(self, X, y):
        # Calculate b using GD
        for i in range(self.epochs):
            lose_slope = -2 * np.sum(y - (self.m * X.ravel() + self.b))
            self.b = self.b - (self.lr * lose_slope)
            print(lose_slope, self.b)

        print(self.b)

# %%
gd = GDRegressor(0.001, 100)

# %%
gd.fit(X, y)
# Out:
# -23724.16214066415 -96.27583785933585
# -18979.329712531322 -77.29650814680453
# -15183.463770025057 -62.11304437677947
# -12146.771016020046 -49.96627336075942
# -9717.416812816035 -40.24885654794339
# -7773.933450252828 -32.474923097690564
# -6219.146760202262 -26.2557763374883
# -4975.317408161811 -21.28045892932649
# -3980.2539265294477 -17.300205002797043
# -3184.2031412235583 -14.116001861573483
# -2547.362512978847 -11.568639348594637
# -2037.8900103830774 -9.53074933821156
# -1630.3120083064618 -7.900437329905098
# -1304.2496066451695 -6.596187723259929
# -1043.3996853161361 -5.552788037943793
# -834.7197482529086 -4.718068289690884
# -667.775798602327 -4.050292491088557
# -534.2206388818614 -3.5160718522066956
# -427.37651110548916 -3.0886953411012064
# -341.9012088843914 -2.746794132216815
# -273.52096710751306 -2.4732731651093016
# -218.81677368601063 -2.254456391423291
# -175.05341894880823 -2.0794029724744827
# -140.04273515904674 -1.939360237315436
# -112.03418812723721 -1.8273260491881986
# -89.62735050179 -1.7376986986864087
# -71.70188040143175 -1.665996818284977
# -57.36150432114527 -1.6086353139638316
# -45.88920345691635 -1.5627461105069154
# -36.71136276553311 -1.5260347477413823
# -29.369090212426567 -1.4966656575289556
# -23.4952721699412 -1.4731703853590143
# -18.79621773595277 -1.4543741676230615
# -15.036974188762137 -1.4393371934342993
# -12.029579351009847 -1.4273076140832894
# -9.623663480808133 -1.4176839506024812
# -7.698930784646322 -1.409985019817835
# -6.159144627716778 -1.4038258751901183
# -4.927315702173608 -1.3988985594879446
# -3.9418525617391076 -1.3949567069262054
# -3.1534820493913926 -1.391803224876814
# -2.5227856395129393 -1.389280439237301
