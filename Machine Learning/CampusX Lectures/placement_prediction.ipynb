# %%
import numpy as np
import pandas as pd

data = pd.DataFrame({
    'Student_Name': ['Ali', 'Sara', 'Ahmed', 'Fatima', 'Hassan', 
                     'Ayesha', 'Bilal', 'Zainab', 'Usman', 'Nida'],
    'CGPA': [8.5, 9.2, 6.5, 7.8, 5.5, 8.9, 6.0, 9.5, 7.0, 8.2],
    'Coding_Score': [85, 92, 45, 78, 35, 88, 50, 95, 65, 80],
    'Projects': [3, 4, 1, 2, 0, 3, 1, 5, 2, 3],
    'Communication_Score': [8, 9, 5, 7, 4, 8, 6, 9, 7, 7],
    'Placed': ['Yes', 'Yes', 'No', 'Yes', 'No', 'Yes', 'No', 'Yes', 'No', 'Yes']
})

data
# Out:
#   Student_Name  CGPA  Coding_Score  Projects  Communication_Score Placed
# 0          Ali   8.5            85         3                    8    Yes
# 1         Sara   9.2            92         4                    9    Yes
# 2        Ahmed   6.5            45         1                    5     No
# 3       Fatima   7.8            78         2                    7    Yes
# 4       Hassan   5.5            35         0                    4     No
# 5       Ayesha   8.9            88         3                    8    Yes
# 6        Bilal   6.0            50         1                    6     No
# 7       Zainab   9.5            95         5                    9    Yes
# 8        Usman   7.0            65         2                    7     No
# 9         Nida   8.2            80         3                    7    Yes

# %%
data.shape
# Out:
# (10, 6)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 6 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Student_Name         10 non-null     object
#  1   CGPA                 10 non-null     float64
#  2   Coding_Score         10 non-null     int64
#  3   Projects             10 non-null     int64
#  4   Communication_Score  10 non-null     int64
#  5   Placed               10 non-null     object
# dtypes: float64(1), int64(3), object(2)
# memory usage: 612.0+ bytes

# %%
data.columns.tolist()
# Out:
# ['Student_Name',
#  'CGPA',
#  'Coding_Score',
#  'Projects',
#  'Communication_Score',
#  'Placed']

# %%
X = data[['CGPA', 'Coding_Score', 'Projects', 'Communication_Score']]
y = data["Placed"]
y
# Out:
# 0    Yes
# 1    Yes
# 2     No
# 3    Yes
# 4     No
# 5    Yes
# 6     No
# 7    Yes
# 8     No
# 9    Yes
# Name: Placed, dtype: object

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

scaler.fit(X)

X_scaled = scaler.transform(X)
X_scaled_df = pd.DataFrame(X_scaled, columns=X.columns)
X_scaled_df
# Out:
#        CGPA  Coding_Score  Projects  Communication_Score
# 0  0.597372      0.678243  0.420084             0.645497
# 1  1.126688      1.024790  1.120224             1.290994
# 2 -0.914962     -1.302028 -0.980196            -1.290994
# 3  0.068055      0.331695 -0.280056             0.000000
# 4 -1.671128     -1.797096 -1.680336            -1.936492
# 5  0.899838      0.826763  0.420084             0.645497
# 6 -1.293045     -1.054494 -0.980196            -0.645497
# 7  1.353538      1.173310  1.820364             1.290994
# 8 -0.536878     -0.311893 -0.280056             0.000000
# 9  0.370522      0.430709  0.420084             0.000000

# %%
scaler.fit(y)

# %%
scaled_math = scaler.transform(data["Math"])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Math'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_11903/3856656865.py in <cell line: 0>()
# ----> 1 scaled_math = scaler.transform(data["Math"])
#
# ...
