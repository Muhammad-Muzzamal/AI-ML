# %% [markdown]
# # Day 07

# %% [markdown]
# ## Chanlanges in Machine Learning

# %% [markdown]
# ### Data gathering
#  -----------------
#  in Simple we take data from plateforms like keggle and may be data is provided by some seniors
#
#  ---
#  but **Data Collection** is most important and serious part of Machine Learning
#  Because we have to gather data from:
#  - APIs
#  - From Web Scrapping

# %% [markdown]
# ### Insufficient Data / Labelled Data
# ---
# let suppose we have two models or Alogorithms
# 1. **A** (with less Data) -> with efficient performance
# 2. **B** (with more data) -> with low performance
#
# so the algorithm taht has large amount of data obviously give good result ot trained batter even it has low performance
